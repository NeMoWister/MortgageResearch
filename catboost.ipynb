# %%
# ! pip install catboost

# %%
import warnings
import pandas as pd
from catboost import CatBoostClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc, roc_curve
import plotly.express as px

# %%
def graphic_roc_auc(y_test, y_pred):
    fpr, tpr, _ = roc_curve(y_test, y_pred)
    # False Positive Rate - доля ложно положительных ответов
    # True Positive Rate - доля истинно положительных ответов

    # закрашенная область
    fig = px.area(
        x=fpr,  # значения оси x
        y=tpr,  # значения оси y
        title=f'ROC Curve (AUC={auc(fpr, tpr):.4f})',  # название графика
        labels=dict(x='False Positive Rate', y='True Positive Rate'),  # названия осей
        width=700,  # ширина
        height=500,  # высота
    )

    # пунктирная линия
    fig.add_shape(
        type='line',  # тип объекта
        line=dict(dash='dash'),  # характеристики линии
        x0=0, x1=1, y0=0, y1=1,  # координаты - откуда и куда рисовать
    )

    fig.update_yaxes(scaleanchor='x', scaleratio=1)
    fig.update_xaxes(constrain='domain')

    fig.show()

# %%
def get_train_test(df_catboost: pd.DataFrame) -> (pd.DataFrame, pd.DataFrame,
                                                 pd.Series, pd.Series):
    """Получаем тренировочные и тестовые наборы данных"""

    train_df = df_catboost.iloc[:int(len(df_catboost) * 0.72)] # делим тренировочный датасет
    test_df = df_catboost.iloc[int(len(df_catboost) * 0.72):]

    train_labels = train_df['target'] # таргеты
    test_labels = test_df['target']
    train_df.drop(['target'], axis=1, inplace=True) # дропаем колонки
    test_df.drop(['target'], axis=1, inplace=True)
    return train_df, test_df, train_labels, test_labels

# %%
warnings.filterwarnings("ignore") # отключение предупреждений


df_catboost = pd.read_csv('train.csv', index_col=0)


cat_features = [ # категориальные признаки
        'applicant_ethnicity',
        'applicant_race_1',
        'applicant_sex',
        'co_applicant_ethnicity',
        'co_applicant_race_1',
        'co_applicant_sex',
        'loan_purpose',
        'loan_type',
        'msamd',
        'preapproval',
        'property_type',
        'purchaser_type'
        ]

# %%
df_catboost['income'].fillna(df_catboost['income'].median(), inplace=True)
df_catboost['income'] = df_catboost['income'].astype(int)


# df_catboost['hud_median_family_income'].fillna(df_catboost['hud_median_family_income'].median(), inplace=True)


# df_catboost['income_ratio_to_average'] = df_catboost['hud_median_family_income'] // df_catboost['income']
# df_catboost['income_ratio_to_average'].fillna(df_catboost['income_ratio_to_average'].median(), inplace=True)


for feature in cat_features:

    df_catboost[feature].fillna(df_catboost[feature].mode().iloc[0], inplace=True) # заполняем модой, на всякий случай

    df_catboost[feature] = df_catboost[feature].astype(int)

# %%
train_df, test_df, train_labels, test_labels = get_train_test(df_catboost)

# initialize CatBoostClassifier
model_v1 = CatBoostClassifier(random_seed=42, iterations=250, depth=8, learning_rate=0.4, boosting_type='Ordered', bootstrap_type='Bernoulli', eval_metric='AUC', task_type='GPU')


# fit model
model_v1.fit(train_df, train_labels, cat_features=cat_features, eval_set=(test_df, test_labels))


predictions = model_v1.predict_proba(test_df) # получаем предсказания


print(f"ROC_AUC_score = {roc_auc_score(test_labels, predictions[:,1])}\n")

graphic_roc_auc(test_labels, predictions[:,1]) # рисуем график
# Out:
# Default metric period is 5 because AUC is/are not implemented for GPU
# 0:	test: 0.9022748	best: 0.9022748 (0)	total: 331ms	remaining: 1m 22s
# 1:	total: 624ms	remaining: 1m 17s
# 2:	total: 940ms	remaining: 1m 17s
# 3:	total: 1.2s	remaining: 1m 14s
# 4:	total: 1.5s	remaining: 1m 13s
# 5:	test: 0.9174294	best: 0.9174294 (5)	total: 1.78s	remaining: 1m 12s
# 6:	total: 2.08s	remaining: 1m 12s
# 7:	total: 2.37s	remaining: 1m 11s
# 8:	total: 2.65s	remaining: 1m 10s
# 9:	total: 2.94s	remaining: 1m 10s
# 10:	test: 0.9199529	best: 0.9199529 (10)	total: 3.23s	remaining: 1m 10s
# 11:	total: 3.48s	remaining: 1m 9s
# 12:	total: 3.77s	remaining: 1m 8s
# 13:	total: 4.07s	remaining: 1m 8s
# 14:	total: 4.36s	remaining: 1m 8s
# 15:	test: 0.9210098	best: 0.9210098 (15)	total: 4.64s	remaining: 1m 7s
# 16:	total: 4.91s	remaining: 1m 7s
# 17:	total: 5.18s	remaining: 1m 6s
# 18:	total: 5.44s	remaining: 1m 6s
# 19:	total: 5.69s	remaining: 1m 5s
# 20:	test: 0.9216356	best: 0.9216356 (20)	total: 5.98s	remaining: 1m 5s
# 21:	total: 6.27s	remaining: 1m 4s
# 22:	total: 6.54s	remaining: 1m 4s
# 23:	total: 6.85s	remaining: 1m 4s
# 24:	total: 7.1s	remaining: 1m 3s
# 25:	test: 0.9220986	best: 0.9220986 (25)	total: 7.36s	remaining: 1m 3s
# 26:	total: 7.59s	remaining: 1m 2s
# 27:	total: 7.85s	remaining: 1m 2s
# 28:	total: 8.09s	remaining: 1m 1s
# 29:	total: 8.33s	remaining: 1m 1s
# 30:	test: 0.9224488	best: 0.9224488 (30)	total: 8.55s	remaining: 1m
# 31:	total: 8.81s	remaining: 1m
# 32:	total: 9.01s	remaining: 59.3s
# 33:	total: 9.27s	remaining: 58.9s
# 34:	total: 9.51s	remaining: 58.4s
# 35:	test: 0.9227247	best: 0.9227247 (35)	total: 9.77s	remaining: 58.1s
# 36:	total: 10s	remaining: 57.7s
# 37:	total: 10.3s	remaining: 57.2s
# 38:	total: 10.5s	remaining: 56.7s
# 39:	total: 10.7s	remaining: 56.3s
# 40:	test: 0.9228922	best: 0.9228922 (40)	total: 11s	remaining: 55.9s
# 41:	total: 11.2s	remaining: 55.5s
# 42:	total: 11.4s	remaining: 55.1s
# 43:	total: 11.7s	remaining: 54.8s
# 44:	total: 12s	remaining: 54.5s
# 45:	test: 0.9230933	best: 0.9230933 (45)	total: 12.1s	remaining: 53.8s
# 46:	total: 12.2s	remaining: 52.7s
# 47:	total: 12.3s	remaining: 51.8s
# 48:	total: 12.5s	remaining: 51.3s
# 49:	total: 12.8s	remaining: 51s
# 50:	test: 0.9231888	best: 0.9231888 (50)	total: 13s	remaining: 50.8s
# 51:	total: 13.3s	remaining: 50.5s
# 52:	total: 13.5s	remaining: 50.1s
# 53:	total: 13.7s	remaining: 49.7s
# 54:	total: 13.9s	remaining: 49.3s
# 55:	test: 0.9232050	best: 0.9232050 (55)	total: 14.1s	remaining: 48.9s
# 56:	total: 14.3s	remaining: 48.3s
# 57:	total: 14.4s	remaining: 47.6s
# 58:	total: 14.6s	remaining: 47.4s
# 59:	total: 14.9s	remaining: 47.1s
# 60:	test: 0.9233720	best: 0.9233720 (60)	total: 15.1s	remaining: 46.8s
# 61:	total: 15.3s	remaining: 46.4s
# 62:	total: 15.5s	remaining: 45.9s
# 63:	total: 15.7s	remaining: 45.7s
# 64:	total: 15.9s	remaining: 45.3s
# 65:	test: 0.9234178	best: 0.9234178 (65)	total: 16.1s	remaining: 45s
# 66:	total: 16.4s	remaining: 44.8s
# 67:	total: 16.6s	remaining: 44.5s
# 68:	total: 16.8s	remaining: 44.1s
# 69:	total: 17.1s	remaining: 43.9s
# 70:	test: 0.9234822	best: 0.9234822 (70)	total: 17.3s	remaining: 43.7s
# 71:	total: 17.6s	remaining: 43.4s
# 72:	total: 17.8s	remaining: 43.2s
# 73:	total: 18.1s	remaining: 42.9s
# 74:	total: 18.3s	remaining: 42.7s
# 75:	test: 0.9236855	best: 0.9236855 (75)	total: 18.6s	remaining: 42.5s
# 76:	total: 18.8s	remaining: 42.3s
# 77:	total: 19.1s	remaining: 42.1s
# 78:	total: 19.3s	remaining: 41.8s
# 79:	total: 19.5s	remaining: 41.5s
# 80:	test: 0.9237670	best: 0.9237670 (80)	total: 19.8s	remaining: 41.3s
# 81:	total: 20s	remaining: 41s
# 82:	total: 20.3s	remaining: 40.8s
# 83:	total: 20.5s	remaining: 40.5s
# 84:	total: 20.7s	remaining: 40.2s
# 85:	test: 0.9238483	best: 0.9238483 (85)	total: 20.9s	remaining: 39.9s
# 86:	total: 21.2s	remaining: 39.6s
# 87:	total: 21.4s	remaining: 39.4s
# 88:	total: 21.6s	remaining: 39.1s
# 89:	total: 21.8s	remaining: 38.8s
# 90:	test: 0.9238939	best: 0.9238939 (90)	total: 22s	remaining: 38.5s
# 91:	total: 22.3s	remaining: 38.2s
# 92:	total: 22.5s	remaining: 37.9s
# 93:	total: 22.7s	remaining: 37.7s
# 94:	total: 22.9s	remaining: 37.4s
# 95:	test: 0.9239285	best: 0.9239285 (95)	total: 23.2s	remaining: 37.2s
# 96:	total: 23.4s	remaining: 36.9s
# 97:	total: 23.6s	remaining: 36.6s
# 98:	total: 23.8s	remaining: 36.3s
# 99:	total: 24s	remaining: 36.1s
# 100:	test: 0.9240279	best: 0.9240279 (100)	total: 24.3s	remaining: 35.8s
# 101:	total: 24.5s	remaining: 35.6s
# 102:	total: 24.8s	remaining: 35.4s
# 103:	total: 25s	remaining: 35.1s
# 104:	total: 25.2s	remaining: 34.8s
# 105:	test: 0.9240644	best: 0.9240644 (105)	total: 25.4s	remaining: 34.5s
# 106:	total: 25.6s	remaining: 34.2s
# 107:	total: 25.8s	remaining: 34s
# 108:	total: 26.1s	remaining: 33.7s
# 109:	total: 26.3s	remaining: 33.5s
# 110:	test: 0.9241600	best: 0.9241600 (110)	total: 26.5s	remaining: 33.2s
# 111:	total: 26.7s	remaining: 32.9s
# 112:	total: 26.9s	remaining: 32.6s
# 113:	total: 27.1s	remaining: 32.4s
# 114:	total: 27.4s	remaining: 32.1s
# 115:	test: 0.9242136	best: 0.9242136 (115)	total: 27.6s	remaining: 31.9s
# 116:	total: 27.8s	remaining: 31.6s
# 117:	total: 28.1s	remaining: 31.4s
# 118:	total: 28.3s	remaining: 31.1s
# 119:	total: 28.5s	remaining: 30.9s
# 120:	test: 0.9242522	best: 0.9242522 (120)	total: 28.7s	remaining: 30.6s
# 121:	total: 28.9s	remaining: 30.4s
# 122:	total: 29.2s	remaining: 30.1s
# 123:	total: 29.4s	remaining: 29.9s
# 124:	total: 29.6s	remaining: 29.6s
# 125:	test: 0.9242654	best: 0.9242654 (125)	total: 29.9s	remaining: 29.4s
# 126:	total: 30.1s	remaining: 29.1s
# 127:	total: 30.3s	remaining: 28.8s
# 128:	total: 30.5s	remaining: 28.6s
# 129:	total: 30.7s	remaining: 28.3s
# 130:	test: 0.9242905	best: 0.9242905 (130)	total: 30.9s	remaining: 28.1s
# 131:	total: 31s	remaining: 27.7s
# 132:	total: 31.1s	remaining: 27.3s
# 133:	total: 31.3s	remaining: 27.1s
# 134:	total: 31.6s	remaining: 26.9s
# 135:	test: 0.9243579	best: 0.9243579 (135)	total: 31.8s	remaining: 26.7s
# 136:	total: 32s	remaining: 26.4s
# 137:	total: 32.3s	remaining: 26.2s
# 138:	total: 32.5s	remaining: 25.9s
# 139:	total: 32.7s	remaining: 25.7s
# 140:	test: 0.9243630	best: 0.9243630 (140)	total: 32.9s	remaining: 25.5s
# 141:	total: 33.2s	remaining: 25.2s
# 142:	total: 33.4s	remaining: 25s
# 143:	total: 33.7s	remaining: 24.8s
# 144:	total: 33.9s	remaining: 24.5s
# 145:	test: 0.9243918	best: 0.9243918 (145)	total: 34.2s	remaining: 24.3s
# 146:	total: 34.4s	remaining: 24.1s
# 147:	total: 34.6s	remaining: 23.9s
# 148:	total: 34.9s	remaining: 23.6s
# 149:	total: 35.1s	remaining: 23.4s
# 150:	test: 0.9244283	best: 0.9244283 (150)	total: 35.4s	remaining: 23.2s
# 151:	total: 35.6s	remaining: 23s
# 152:	total: 35.9s	remaining: 22.7s
# 153:	total: 36.1s	remaining: 22.5s
# 154:	total: 36.3s	remaining: 22.3s
# 155:	test: 0.9244620	best: 0.9244620 (155)	total: 36.6s	remaining: 22.1s
# 156:	total: 36.8s	remaining: 21.8s
# 157:	total: 37.1s	remaining: 21.6s
# 158:	total: 37.3s	remaining: 21.4s
# 159:	total: 37.6s	remaining: 21.1s
# 160:	test: 0.9244700	best: 0.9244700 (160)	total: 37.8s	remaining: 20.9s
# 161:	total: 37.9s	remaining: 20.6s
# 162:	total: 38.1s	remaining: 20.3s
# 163:	total: 38.4s	remaining: 20.1s
# 164:	total: 38.6s	remaining: 19.9s
# 165:	test: 0.9244769	best: 0.9244769 (165)	total: 38.8s	remaining: 19.6s
# 166:	total: 39s	remaining: 19.4s
# 167:	total: 39.2s	remaining: 19.2s
# 168:	total: 39.5s	remaining: 18.9s
# 169:	total: 39.7s	remaining: 18.7s
# 170:	test: 0.9244839	best: 0.9244839 (170)	total: 39.9s	remaining: 18.5s
# 171:	total: 40.1s	remaining: 18.2s
# 172:	total: 40.4s	remaining: 18s
# 173:	total: 40.6s	remaining: 17.7s
# 174:	total: 40.8s	remaining: 17.5s
# 175:	test: 0.9244831	best: 0.9244839 (170)	total: 41s	remaining: 17.2s
# 176:	total: 41.2s	remaining: 17s
# 177:	total: 41.5s	remaining: 16.8s
# 178:	total: 41.7s	remaining: 16.5s
# 179:	total: 41.9s	remaining: 16.3s
# 180:	test: 0.9245653	best: 0.9245653 (180)	total: 42.2s	remaining: 16.1s
# 181:	total: 42.4s	remaining: 15.8s
# 182:	total: 42.6s	remaining: 15.6s
# 183:	total: 42.8s	remaining: 15.4s
# 184:	total: 43s	remaining: 15.1s
# 185:	test: 0.9245645	best: 0.9245653 (180)	total: 43.2s	remaining: 14.9s
# 186:	total: 43.5s	remaining: 14.6s
# 187:	total: 43.7s	remaining: 14.4s
# 188:	total: 43.9s	remaining: 14.2s
# 189:	total: 44.1s	remaining: 13.9s
# 190:	test: 0.9245682	best: 0.9245682 (190)	total: 44.4s	remaining: 13.7s
# 191:	total: 44.6s	remaining: 13.5s
# 192:	total: 44.7s	remaining: 13.2s
# 193:	total: 44.9s	remaining: 13s
# 194:	total: 45.2s	remaining: 12.7s
# 195:	test: 0.9245707	best: 0.9245707 (195)	total: 45.4s	remaining: 12.5s
# 196:	total: 45.6s	remaining: 12.3s
# 197:	total: 45.8s	remaining: 12s
# 198:	total: 46s	remaining: 11.8s
# 199:	total: 46.2s	remaining: 11.5s
# 200:	test: 0.9245705	best: 0.9245707 (195)	total: 46.4s	remaining: 11.3s
# 201:	total: 46.6s	remaining: 11.1s
# 202:	total: 46.8s	remaining: 10.8s
# 203:	total: 47s	remaining: 10.6s
# 204:	total: 47.3s	remaining: 10.4s
# 205:	test: 0.9245921	best: 0.9245921 (205)	total: 47.5s	remaining: 10.1s
# 206:	total: 47.7s	remaining: 9.91s
# 207:	total: 47.9s	remaining: 9.68s
# 208:	total: 48.2s	remaining: 9.45s
# 209:	total: 48.4s	remaining: 9.21s
# 210:	test: 0.9246079	best: 0.9246079 (210)	total: 48.6s	remaining: 8.97s
# 211:	total: 48.7s	remaining: 8.74s
# 212:	total: 49s	remaining: 8.51s
# 213:	total: 49.2s	remaining: 8.28s
# 214:	total: 49.4s	remaining: 8.04s
# 215:	test: 0.9246135	best: 0.9246135 (215)	total: 49.6s	remaining: 7.81s
# 216:	total: 49.8s	remaining: 7.57s
# 217:	total: 50s	remaining: 7.33s
# 218:	total: 50.2s	remaining: 7.1s
# 219:	total: 50.4s	remaining: 6.88s
# 220:	test: 0.9246264	best: 0.9246264 (220)	total: 50.7s	remaining: 6.65s
# 221:	total: 50.9s	remaining: 6.42s
# 222:	total: 51.1s	remaining: 6.19s
# 223:	total: 51.4s	remaining: 5.96s
# 224:	total: 51.6s	remaining: 5.73s
# 225:	test: 0.9246287	best: 0.9246287 (225)	total: 51.8s	remaining: 5.5s
# 226:	total: 52s	remaining: 5.26s
# 227:	total: 52.2s	remaining: 5.04s
# 228:	total: 52.4s	remaining: 4.81s
# 229:	total: 52.7s	remaining: 4.58s
# 230:	test: 0.9246374	best: 0.9246374 (230)	total: 52.9s	remaining: 4.35s
# 231:	total: 53.1s	remaining: 4.12s
# 232:	total: 53.4s	remaining: 3.9s
# 233:	total: 53.6s	remaining: 3.67s
# 234:	total: 53.9s	remaining: 3.44s
# 235:	test: 0.9246843	best: 0.9246843 (235)	total: 54.1s	remaining: 3.21s
# 236:	total: 54.3s	remaining: 2.98s
# 237:	total: 54.5s	remaining: 2.75s
# 238:	total: 54.7s	remaining: 2.52s
# 239:	total: 54.9s	remaining: 2.29s
# 240:	test: 0.9246970	best: 0.9246970 (240)	total: 55.1s	remaining: 2.06s
# 241:	total: 55.4s	remaining: 1.83s
# 242:	total: 55.7s	remaining: 1.6s
# 243:	total: 55.9s	remaining: 1.37s
# 244:	total: 56.1s	remaining: 1.15s
# 245:	test: 0.9247668	best: 0.9247668 (245)	total: 56.3s	remaining: 916ms
# 246:	total: 56.6s	remaining: 687ms
# 247:	total: 56.8s	remaining: 458ms
# 248:	total: 57s	remaining: 229ms
# 249:	test: 0.9247921	best: 0.9247921 (249)	total: 57.2s	remaining: 0us
# bestTest = 0.9247920513
# bestIteration = 249
# ROC_AUC_score = 0.9247919971742498

# %%
# тесты

df_catboost_test = pd.read_csv('test.csv', index_col=0)

df_catboost_test['income'].fillna(df_catboost_test['income'].median(), inplace=True)


# df_catboost_test['hud_median_family_income'].fillna(df_catboost_test['hud_median_family_income'].median(), inplace=True)


# df_catboost_test['income_ratio_to_average'] = df_catboost_test['hud_median_family_income'] // df_catboost_test['income']
# df_catboost_test['income_ratio_to_average'].fillna(df_catboost_test['income_ratio_to_average'].median(), inplace=True)


for feature in cat_features:

    df_catboost_test[feature].fillna(df_catboost_test[feature].mode().iloc[0], inplace=True)

    df_catboost_test[feature] = df_catboost_test[feature].astype(int)


df_catboost_test['target'] = model_v1.predict_proba(df_catboost_test)[:, 1]

df_catboost_test.target.to_csv('submission.csv')

# %%
# !zip submission.zip submission.csv
