# %%
# ! pip install catboost
import warnings
import pandas as pd
from catboost import CatBoostClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc, roc_curve
import plotly.express as px


def graphic_roc_auc(y_test, y_pred):
    fpr, tpr, _ = roc_curve(y_test, y_pred)
    # False Positive Rate - доля ложно положительных ответов
    # True Positive Rate - доля истинно положительных ответов

    # закрашенная область
    fig = px.area(
        x=fpr,  # значения оси x
        y=tpr,  # значения оси y
        title=f'ROC Curve (AUC={auc(fpr, tpr):.4f})',  # название графика
        labels=dict(x='False Positive Rate', y='True Positive Rate'),  # названия осей
        width=700,  # ширина
        height=500,  # высота
    )

    # пунктирная линия
    fig.add_shape(
        type='line',  # тип объекта
        line=dict(dash='dash'),  # характеристики линии
        x0=0, x1=1, y0=0, y1=1,  # координаты - откуда и куда рисовать
    )

    fig.update_yaxes(scaleanchor='x', scaleratio=1)
    fig.update_xaxes(constrain='domain')

    fig.show()


def get_train_test(df_catboost: pd.DataFrame) -> (pd.DataFrame, pd.DataFrame,
                                                 pd.Series, pd.Series):
    """Получаем тренировочные и тестовые наборы данных"""

    train_df = df_catboost.iloc[:int(len(df_catboost) * 0.72)] # делим тренировочный датасет
    test_df = df_catboost.iloc[int(len(df_catboost) * 0.72):]

    train_labels = train_df['target'] # таргеты
    test_labels = test_df['target']
    train_df.drop(['target'], axis=1, inplace=True) # дропаем колонки
    test_df.drop(['target'], axis=1, inplace=True)
    return train_df, test_df, train_labels, test_labels


warnings.filterwarnings("ignore") # отключение предупреждений


df_catboost = pd.read_csv('train.csv', index_col=0)


cat_features = [ # категориальные признаки
        'applicant_ethnicity',
        'applicant_race_1',
        'applicant_sex',
        'co_applicant_ethnicity',
        'co_applicant_race_1',
        'co_applicant_sex',
        'loan_purpose',
        'loan_type',
        'msamd',
        'preapproval',
        'property_type',
        'purchaser_type'
        ]

# applicant_race_3, applicant_race_4, applicant_race_5, co_applicant_race_2, co_applicant_race_3, co_applicant_race_4, co_applicant_race_5

# по сути категориальный признак, но мы его таковым не считаем. подавляющее количество null значений, столбец надо либо дропать, либо использовать как числовое значение и отдать на растерзание catboostу


df_catboost['income'].fillna(df_catboost['income'].median(), inplace=True)
df_catboost['income'] = df_catboost['income'].astype(int)


# df_catboost['hud_median_family_income'].fillna(df_catboost['hud_median_family_income'].median(), inplace=True)


# df_catboost['income_ratio_to_average'] = df_catboost['hud_median_family_income'] // df_catboost['income']
# df_catboost['income_ratio_to_average'].fillna(df_catboost['income_ratio_to_average'].median(), inplace=True)


for feature in cat_features:

    df_catboost[feature].fillna(df_catboost[feature].mode().iloc[0], inplace=True) # заполняем модой, на всякий случай

    df_catboost[feature] = df_catboost[feature].astype(int)


train_df, test_df, train_labels, test_labels = get_train_test(df_catboost)

# initialize CatBoostClassifier
model_v1 = CatBoostClassifier(random_seed=42, iterations=250, depth=8, learning_rate=0.4, boosting_type='Ordered', bootstrap_type='Bernoulli', eval_metric='AUC', task_type='GPU')


# fit model
model_v1.fit(train_df, train_labels, cat_features=cat_features, eval_set=(test_df, test_labels))


predictions = model_v1.predict_proba(test_df) # получаем предсказания


print(f"ROC_AUC_score = {roc_auc_score(test_labels, predictions[:,1])}\n")

graphic_roc_auc(test_labels, predictions[:,1]) # рисуем график


# тесты

df_catboost_test = pd.read_csv('test.csv', index_col=0)

df_catboost_test['income'].fillna(df_catboost_test['income'].median(), inplace=True)


# df_catboost_test['hud_median_family_income'].fillna(df_catboost_test['hud_median_family_income'].median(), inplace=True)


# df_catboost_test['income_ratio_to_average'] = df_catboost_test['hud_median_family_income'] // df_catboost_test['income']
# df_catboost_test['income_ratio_to_average'].fillna(df_catboost_test['income_ratio_to_average'].median(), inplace=True)


for feature in cat_features:

    df_catboost_test[feature].fillna(df_catboost_test[feature].mode().iloc[0], inplace=True)

    df_catboost_test[feature] = df_catboost_test[feature].astype(int)


df_catboost_test['target'] = model_v1.predict_proba(df_catboost_test)[:, 1]

df_catboost_test.target.to_csv('submission.csv')
# Out:
# Default metric period is 5 because AUC is/are not implemented for GPU
# 0:	test: 0.9022748	best: 0.9022748 (0)	total: 262ms	remaining: 1m 5s
# 1:	total: 539ms	remaining: 1m 6s
# 2:	total: 794ms	remaining: 1m 5s
# 3:	total: 1.01s	remaining: 1m 2s
# 4:	total: 1.25s	remaining: 1m 1s
# 5:	test: 0.9174294	best: 0.9174294 (5)	total: 1.51s	remaining: 1m 1s
# 6:	total: 1.77s	remaining: 1m 1s
# 7:	total: 2s	remaining: 1m
# 8:	total: 2.25s	remaining: 1m
# 9:	total: 2.5s	remaining: 59.9s
# 10:	test: 0.9199529	best: 0.9199529 (10)	total: 2.75s	remaining: 59.7s
# 11:	total: 2.96s	remaining: 58.7s
# 12:	total: 3.22s	remaining: 58.6s
# 13:	total: 3.46s	remaining: 58.4s
# 14:	total: 3.71s	remaining: 58.1s
# 15:	test: 0.9210098	best: 0.9210098 (15)	total: 3.95s	remaining: 57.8s
# 16:	total: 4.18s	remaining: 57.4s
# 17:	total: 4.4s	remaining: 56.8s
# 18:	total: 4.63s	remaining: 56.3s
# 19:	total: 4.86s	remaining: 55.8s
# 20:	test: 0.9216356	best: 0.9216356 (20)	total: 5.1s	remaining: 55.6s
# 21:	total: 5.34s	remaining: 55.4s
# 22:	total: 5.58s	remaining: 55.1s
# 23:	total: 5.82s	remaining: 54.8s
# 24:	total: 6.07s	remaining: 54.6s
# 25:	test: 0.9220986	best: 0.9220986 (25)	total: 6.3s	remaining: 54.3s
# 26:	total: 6.53s	remaining: 54s
# 27:	total: 6.79s	remaining: 53.9s
# 28:	total: 7.03s	remaining: 53.6s
# 29:	total: 7.27s	remaining: 53.3s
# 30:	test: 0.9224488	best: 0.9224488 (30)	total: 7.49s	remaining: 52.9s
# 31:	total: 7.74s	remaining: 52.7s
# 32:	total: 7.93s	remaining: 52.2s
# 33:	total: 8.18s	remaining: 52s
# 34:	total: 8.41s	remaining: 51.7s
# 35:	test: 0.9227247	best: 0.9227247 (35)	total: 8.66s	remaining: 51.5s
# 36:	total: 8.91s	remaining: 51.3s
# 37:	total: 9.15s	remaining: 51s
# 38:	total: 9.37s	remaining: 50.7s
# 39:	total: 9.61s	remaining: 50.5s
# 40:	test: 0.9228922	best: 0.9228922 (40)	total: 9.85s	remaining: 50.2s
# 41:	total: 10.1s	remaining: 49.9s
# 42:	total: 10.3s	remaining: 49.6s
# 43:	total: 10.6s	remaining: 49.5s
# 44:	total: 10.8s	remaining: 49.2s
# 45:	test: 0.9230933	best: 0.9230933 (45)	total: 11s	remaining: 48.7s
# 46:	total: 11.1s	remaining: 47.8s
# 47:	total: 11.1s	remaining: 46.9s
# 48:	total: 11.3s	remaining: 46.6s
# 49:	total: 11.6s	remaining: 46.4s
# 50:	test: 0.9231888	best: 0.9231888 (50)	total: 11.8s	remaining: 46.2s
# 51:	total: 12.1s	remaining: 46s
# 52:	total: 12.3s	remaining: 45.8s
# 53:	total: 12.5s	remaining: 45.4s
# 54:	total: 12.7s	remaining: 45s
# 55:	test: 0.9232050	best: 0.9232050 (55)	total: 12.9s	remaining: 44.8s
# 56:	total: 13.1s	remaining: 44.3s
# 57:	total: 13.2s	remaining: 43.7s
# 58:	total: 13.4s	remaining: 43.5s
# 59:	total: 13.7s	remaining: 43.3s
# 60:	test: 0.9233720	best: 0.9233720 (60)	total: 13.9s	remaining: 43s
# 61:	total: 14.1s	remaining: 42.7s
# 62:	total: 14.3s	remaining: 42.3s
# 63:	total: 14.5s	remaining: 42.2s
# 64:	total: 14.7s	remaining: 41.8s
# 65:	test: 0.9234178	best: 0.9234178 (65)	total: 14.9s	remaining: 41.5s
# 66:	total: 15.1s	remaining: 41.3s
# 67:	total: 15.4s	remaining: 41.1s
# 68:	total: 15.6s	remaining: 40.8s
# 69:	total: 15.8s	remaining: 40.6s
# 70:	test: 0.9234822	best: 0.9234822 (70)	total: 16.1s	remaining: 40.5s
# 71:	total: 16.3s	remaining: 40.3s
# 72:	total: 16.5s	remaining: 40.1s
# 73:	total: 16.8s	remaining: 39.9s
# 74:	total: 17s	remaining: 39.7s
# 75:	test: 0.9236855	best: 0.9236855 (75)	total: 17.3s	remaining: 39.6s
# 76:	total: 17.5s	remaining: 39.4s
# 77:	total: 17.8s	remaining: 39.2s
# 78:	total: 18s	remaining: 39s
# 79:	total: 18.2s	remaining: 38.7s
# 80:	test: 0.9237670	best: 0.9237670 (80)	total: 18.5s	remaining: 38.5s
# 81:	total: 18.7s	remaining: 38.3s
# 82:	total: 18.9s	remaining: 38.1s
# 83:	total: 19.2s	remaining: 37.9s
# 84:	total: 19.4s	remaining: 37.6s
# 85:	test: 0.9238483	best: 0.9238483 (85)	total: 19.6s	remaining: 37.3s
# 86:	total: 19.8s	remaining: 37.1s
# 87:	total: 20s	remaining: 36.9s
# 88:	total: 20.2s	remaining: 36.6s
# 89:	total: 20.5s	remaining: 36.4s
# 90:	test: 0.9238939	best: 0.9238939 (90)	total: 20.7s	remaining: 36.1s
# 91:	total: 20.9s	remaining: 35.9s
# 92:	total: 21.1s	remaining: 35.6s
# 93:	total: 21.4s	remaining: 35.4s
# 94:	total: 21.6s	remaining: 35.2s
# 95:	test: 0.9239285	best: 0.9239285 (95)	total: 21.8s	remaining: 35s
# 96:	total: 22s	remaining: 34.7s
# 97:	total: 22.2s	remaining: 34.5s
# 98:	total: 22.4s	remaining: 34.2s
# 99:	total: 22.7s	remaining: 34s
# 100:	test: 0.9240279	best: 0.9240279 (100)	total: 22.9s	remaining: 33.8s
# 101:	total: 23.2s	remaining: 33.6s
# 102:	total: 23.4s	remaining: 33.4s
# 103:	total: 23.6s	remaining: 33.1s
# 104:	total: 23.8s	remaining: 32.8s
# 105:	test: 0.9240644	best: 0.9240644 (105)	total: 24s	remaining: 32.6s
# 106:	total: 24.2s	remaining: 32.3s
# 107:	total: 24.4s	remaining: 32.1s
# 108:	total: 24.6s	remaining: 31.9s
# 109:	total: 24.9s	remaining: 31.7s
# 110:	test: 0.9241600	best: 0.9241600 (110)	total: 25.1s	remaining: 31.4s
# 111:	total: 25.3s	remaining: 31.2s
# 112:	total: 25.5s	remaining: 30.9s
# 113:	total: 25.7s	remaining: 30.7s
# 114:	total: 26s	remaining: 30.5s
# 115:	test: 0.9242136	best: 0.9242136 (115)	total: 26.2s	remaining: 30.3s
# 116:	total: 26.4s	remaining: 30s
# 117:	total: 26.6s	remaining: 29.8s
# 118:	total: 26.8s	remaining: 29.5s
# 119:	total: 27s	remaining: 29.2s
# 120:	test: 0.9242522	best: 0.9242522 (120)	total: 27.3s	remaining: 29.1s
# 121:	total: 27.4s	remaining: 28.8s
# 122:	total: 27.7s	remaining: 28.6s
# 123:	total: 27.9s	remaining: 28.3s
# 124:	total: 28.1s	remaining: 28.1s
# 125:	test: 0.9242654	best: 0.9242654 (125)	total: 28.4s	remaining: 27.9s
# 126:	total: 28.5s	remaining: 27.6s
# 127:	total: 28.7s	remaining: 27.4s
# 128:	total: 29s	remaining: 27.2s
# 129:	total: 29.2s	remaining: 26.9s
# 130:	test: 0.9242905	best: 0.9242905 (130)	total: 29.3s	remaining: 26.7s
# 131:	total: 29.4s	remaining: 26.3s
# 132:	total: 29.5s	remaining: 26s
# 133:	total: 29.7s	remaining: 25.8s
# 134:	total: 29.9s	remaining: 25.5s
# 135:	test: 0.9243268	best: 0.9243268 (135)	total: 30.2s	remaining: 25.3s
# 136:	total: 30.4s	remaining: 25.1s
# 137:	total: 30.6s	remaining: 24.8s
# 138:	total: 30.8s	remaining: 24.6s
# 139:	total: 31.1s	remaining: 24.4s
# 140:	test: 0.9243770	best: 0.9243770 (140)	total: 31.3s	remaining: 24.2s
# 141:	total: 31.5s	remaining: 24s
# 142:	total: 31.8s	remaining: 23.8s
# 143:	total: 32s	remaining: 23.6s
# 144:	total: 32.2s	remaining: 23.3s
# 145:	test: 0.9244321	best: 0.9244321 (145)	total: 32.5s	remaining: 23.1s
# 146:	total: 32.7s	remaining: 22.9s
# 147:	total: 32.9s	remaining: 22.7s
# 148:	total: 33.1s	remaining: 22.5s
# 149:	total: 33.4s	remaining: 22.3s
# 150:	test: 0.9244583	best: 0.9244583 (150)	total: 33.6s	remaining: 22s
# 151:	total: 33.8s	remaining: 21.8s
# 152:	total: 34.1s	remaining: 21.6s
# 153:	total: 34.3s	remaining: 21.4s
# 154:	total: 34.5s	remaining: 21.2s
# 155:	test: 0.9244834	best: 0.9244834 (155)	total: 34.7s	remaining: 20.9s
# 156:	total: 35s	remaining: 20.7s
# 157:	total: 35.2s	remaining: 20.5s
# 158:	total: 35.4s	remaining: 20.3s
# 159:	total: 35.6s	remaining: 20s
# 160:	test: 0.9245214	best: 0.9245214 (160)	total: 35.8s	remaining: 19.8s
# 161:	total: 36.1s	remaining: 19.6s
# 162:	total: 36.3s	remaining: 19.3s
# 163:	total: 36.4s	remaining: 19.1s
# 164:	total: 36.6s	remaining: 18.9s
# 165:	test: 0.9245481	best: 0.9245481 (165)	total: 36.9s	remaining: 18.7s
# 166:	total: 37s	remaining: 18.4s
# 167:	total: 37.1s	remaining: 18.1s
# 168:	total: 37.4s	remaining: 17.9s
# 169:	total: 37.6s	remaining: 17.7s
# 170:	test: 0.9245623	best: 0.9245623 (170)	total: 37.8s	remaining: 17.5s
# 171:	total: 38.1s	remaining: 17.3s
# 172:	total: 38.3s	remaining: 17s
# 173:	total: 38.5s	remaining: 16.8s
# 174:	total: 38.7s	remaining: 16.6s
# 175:	test: 0.9245703	best: 0.9245703 (175)	total: 39s	remaining: 16.4s
# 176:	total: 39.2s	remaining: 16.1s
# 177:	total: 39.3s	remaining: 15.9s
# 178:	total: 39.6s	remaining: 15.7s
# 179:	total: 39.8s	remaining: 15.5s
# 180:	test: 0.9245687	best: 0.9245703 (175)	total: 40s	remaining: 15.2s
# 181:	total: 40.2s	remaining: 15s
# 182:	total: 40.5s	remaining: 14.8s
# 183:	total: 40.7s	remaining: 14.6s
# 184:	total: 40.9s	remaining: 14.4s
# 185:	test: 0.9245841	best: 0.9245841 (185)	total: 41.1s	remaining: 14.1s
# 186:	total: 41.3s	remaining: 13.9s
# 187:	total: 41.5s	remaining: 13.7s
# 188:	total: 41.8s	remaining: 13.5s
# 189:	total: 42s	remaining: 13.3s
# 190:	test: 0.9246015	best: 0.9246015 (190)	total: 42.2s	remaining: 13s
# 191:	total: 42.4s	remaining: 12.8s
# 192:	total: 42.7s	remaining: 12.6s
# 193:	total: 42.9s	remaining: 12.4s
# 194:	total: 43.1s	remaining: 12.2s
# 195:	test: 0.9246361	best: 0.9246361 (195)	total: 43.3s	remaining: 11.9s
# 196:	total: 43.6s	remaining: 11.7s
# 197:	total: 43.8s	remaining: 11.5s
# 198:	total: 44.1s	remaining: 11.3s
# 199:	total: 44.3s	remaining: 11.1s
# 200:	test: 0.9246441	best: 0.9246441 (200)	total: 44.6s	remaining: 10.9s
# 201:	total: 44.8s	remaining: 10.6s
# 202:	total: 45s	remaining: 10.4s
# 203:	total: 45.3s	remaining: 10.2s
# 204:	total: 45.5s	remaining: 10s
# 205:	test: 0.9246568	best: 0.9246568 (205)	total: 45.7s	remaining: 9.77s
# 206:	total: 45.9s	remaining: 9.54s
# 207:	total: 46.2s	remaining: 9.33s
# 208:	total: 46.4s	remaining: 9.1s
# 209:	total: 46.6s	remaining: 8.87s
# 210:	test: 0.9246575	best: 0.9246575 (210)	total: 46.8s	remaining: 8.65s
# 211:	total: 47s	remaining: 8.43s
# 212:	total: 47.2s	remaining: 8.21s
# 213:	total: 47.4s	remaining: 7.98s
# 214:	total: 47.7s	remaining: 7.76s
# 215:	test: 0.9246857	best: 0.9246857 (215)	total: 47.9s	remaining: 7.54s
# 216:	total: 48.1s	remaining: 7.31s
# 217:	total: 48.3s	remaining: 7.09s
# 218:	total: 48.6s	remaining: 6.88s
# 219:	total: 48.8s	remaining: 6.65s
# 220:	test: 0.9246993	best: 0.9246993 (220)	total: 49s	remaining: 6.42s
# 221:	total: 49.2s	remaining: 6.2s
# 222:	total: 49.3s	remaining: 5.97s
# 223:	total: 49.5s	remaining: 5.75s
# 224:	total: 49.8s	remaining: 5.53s
# 225:	test: 0.9247178	best: 0.9247178 (225)	total: 50s	remaining: 5.31s
# 226:	total: 50.2s	remaining: 5.09s
# 227:	total: 50.4s	remaining: 4.86s
# 228:	total: 50.6s	remaining: 4.64s
# 229:	total: 50.8s	remaining: 4.41s
# 230:	test: 0.9247320	best: 0.9247320 (230)	total: 51s	remaining: 4.19s
# 231:	total: 51.2s	remaining: 3.97s
# 232:	total: 51.4s	remaining: 3.75s
# 233:	total: 51.6s	remaining: 3.53s
# 234:	total: 51.9s	remaining: 3.31s
# 235:	test: 0.9247345	best: 0.9247345 (235)	total: 52s	remaining: 3.09s
# 236:	total: 52.3s	remaining: 2.87s
# 237:	total: 52.5s	remaining: 2.65s
# 238:	total: 52.7s	remaining: 2.42s
# 239:	total: 52.9s	remaining: 2.2s
# 240:	test: 0.9247353	best: 0.9247353 (240)	total: 53.1s	remaining: 1.98s
# 241:	total: 53.4s	remaining: 1.76s
# 242:	total: 53.5s	remaining: 1.54s
# 243:	total: 53.8s	remaining: 1.32s
# 244:	total: 54s	remaining: 1.1s
# 245:	test: 0.9247355	best: 0.9247355 (245)	total: 54.2s	remaining: 881ms
# 246:	total: 54.4s	remaining: 661ms
# 247:	total: 54.6s	remaining: 440ms
# 248:	total: 54.8s	remaining: 220ms
# 249:	test: 0.9247360	best: 0.9247360 (249)	total: 55s	remaining: 0us
# bestTest = 0.9247359633
# bestIteration = 249
# ROC_AUC_score = 0.9247359021327082

# %%
# !zip submission.zip submission.csv
